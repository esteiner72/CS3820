# %%
import csv
with open(r'data/result.csv') as csv_file:
    data_writer = csv.writer(csv_file)
    data_writer.writerow(' ')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[5], line 4
#       2 with open('data/result.csv') as csv_file:
#       3     data_writer = csv.writer(csv_file)
# ----> 4     data_writer.writerow(' ')
#
# UnsupportedOperation: not writable
